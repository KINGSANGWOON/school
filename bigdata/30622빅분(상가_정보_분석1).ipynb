# %% [markdown]
# <a href="https://colab.research.google.com/github/KINGSANGWOON/school/blob/main/bigdata/30622%EB%B9%85%EB%B6%84(%EC%83%81%EA%B0%80_%EC%A0%95%EB%B3%B4_%EB%B6%84%EC%84%9D1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DateFrame = pd.read_csv('/content/drive/MyDrive/data/소상공인시장진흥공단_상가(상권)정보_서울_202112.csv')

df = DateFrame.iloc[:,0:10].head(10)
df 

np.shape(df)
# Out:
# (10, 10)

# %%
df['상가업소번호']
# Out:
# 0    23324279
# 1    24525909
# 2    24715368
# 3    15554136
# 4    17174175
# 5    17174119
# 6    17174096
# 7    17174040
# 8    25530299
# 9    21938782
# Name: 상가업소번호, dtype: int64

# %%
# !apt-get install fonts-nanum* -qq

import matplotlib.font_manager as fm

all_fonts_I_can_use = fm.findSystemFonts(fontpaths=None, fontext='ttf')
all_fonts_I_can_use
# Out:
# ['/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundEB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCoding-Bold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEcoBold.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoEcoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEcoExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicLight.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationSerif-Italic.ttf',
#  '/usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf',
# ...

# %%
plt.title("한글 폰트 설정")
plt.plot([-4,-6,1,2,0,3])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54256 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath,size = 9)
fm._rebuild()

# %config InlneBackend.fingure_format = 'retina'

plt.rc('font',family = 'NanumBarunGothic')

# %%
plt.title("한글 폰트 설정")
plt.plot([-4,-6,1,2,0,3])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
pd.options.display.max_columns = 39

# %%
DateFrame.head()
# Out:
#      상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0  23324279       제중건강원  NaN         D       소매       D10    건강/미용식품
# 1  24525909       민속악기사  NaN         D       소매       D04  취미/오락관련소매
# 2  24715368       태평양진주  NaN         D       소매       D26   시계/귀금속소매
# 3  15554136  김선희꼼꼼국어교습소  NaN         R    학문/교육       R01  학원-보습교습입시
# 4  17174175         비지트  NaN         Q       음식       Q01         한식
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드       표준산업분류명  시도코드    시도명  시군구코드  시군구명  \
# 0    D10A07        건강원   G47216    건강보조식품 소매업    11  서울특별시  11560  영등포구
# 1    D04A09       악기판매   G47593        악기 소매업    11  서울특별시  11200   성동구
# 2    D26A01     시계/귀금속   G47830  시계 및 귀금속 소매업    11  서울특별시  11110   종로구
# 3    R01A01      학원-입시   P85501      일반 교과 학원    11  서울특별시  11710   송파구
# 4    Q01A01  한식/백반/한정식   I56111       한식 음식점업    11  서울특별시  11650   서초구
#
#         행정동코드         행정동명       법정동코드    법정동명                 지번코드  대지구분코드  \
# ...

# %%
DateFrame.tail()
# Out:
#           상가업소번호          상호명  지점명 상권업종대분류코드  상권업종대분류명 상권업종중분류코드    상권업종중분류명  \
# 315289  17915026      사라헤어하우스  NaN         F     생활서비스       F01     이/미용/건강
# 315290  17917525   김현진153필라테스  NaN         N  관광/여가/오락       N05   요가/단전/마사지
# 315291  17913544  26도헤어마곡나루역점  NaN         F     생활서비스       F01     이/미용/건강
# 315292  17958597        명품케터링  NaN         Q        음식       Q13     음식배달서비스
# 315293  17938681      페어즈오브슈즈  NaN         D        소매       D06  가방/신발/액세서리
#
#        상권업종소분류코드 상권업종소분류명 표준산업분류코드       표준산업분류명  시도코드    시도명  시군구코드  시군구명  \
# 315289    F01A01    여성미용실   S96112         두발미용업    11  서울특별시  11620   관악구
# 315290    N05A01    요가/단식   S96129  기타 미용관련 서비스업    11  서울특별시  11740   강동구
# 315291    F01A01    여성미용실   S96112         두발미용업    11  서울특별시  11500   강서구
# 315292    Q13A03   음식출장조달   I56131    출장 음식 서비스업    11  서울특별시  11305   강북구
# 315293    D06A01     신발소매   G47420        신발 소매업    11  서울특별시  11560  영등포구
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
DateFrame.index
# Out:
# RangeIndex(start=0, stop=315294, step=1)

# %%
DateFrame.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
DateFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315294 entries, 0 to 315293
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     315294 non-null  int64
#  1   상호명        315293 non-null  object
#  2   지점명        55561 non-null   object
#  3   상권업종대분류코드  315294 non-null  object
#  4   상권업종대분류명   315294 non-null  object
#  5   상권업종중분류코드  315294 non-null  object
#  6   상권업종중분류명   315294 non-null  object
#  7   상권업종소분류코드  315294 non-null  object
#  8   상권업종소분류명   315294 non-null  object
#  9   표준산업분류코드   296187 non-null  object
#  10  표준산업분류명    296187 non-null  object
#  11  시도코드       315294 non-null  int64
#  12  시도명        315294 non-null  object
#  13  시군구코드      315294 non-null  int64
#  14  시군구명       315294 non-null  object
#  15  행정동코드      315294 non-null  int64
#  16  행정동명       315289 non-null  object
#  17  법정동코드      315294 non-null  int64
#  18  법정동명       315294 non-null  object
# ...

# %%
DateFrame.dtypes
# Out:
# 상가업소번호         int64
# 상호명           object
# 지점명           object
# 상권업종대분류코드     object
# 상권업종대분류명      object
# 상권업종중분류코드     object
# 상권업종중분류명      object
# 상권업종소분류코드     object
# 상권업종소분류명      object
# 표준산업분류코드      object
# 표준산업분류명       object
# 시도코드           int64
# 시도명           object
# 시군구코드          int64
# 시군구명          object
# 행정동코드          int64
# 행정동명          object
# 법정동코드          int64
# 법정동명          object
# 지번코드           int64
# 대지구분코드         int64
# 대지구분명         object
# 지번본번지          int64
# 지번부번지        float64
# 지번주소          object
# 도로명코드          int64
# 도로명           object
# 건물본번지          int64
# 건물부번지        float64
# 건물관리번호        object
# 건물명           object
# 도로명주소         object
# 구우편번호          int64
# 신우편번호        float64
# 동정보           object
# 층정보           object
# 호정보          float64
# 경도           float64
# 위도           float64
# dtype: object

# %%
n = DateFrame.isnull().sum() # isnull null값이 모두 있음

# %%
n.sort_values().plot.barh(figsize=(7,8))

# %%
import missingno as msno #결측치(데이터가 없음을) 확인

msno.matrix(DateFrame) # 지점명은 프렌차이즈가 아닌 이상 없기 때문에 결측치가 많을 수 밖에 없다

# %%
msno.heatmap(DateFrame)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
msno.dendrogram(DateFrame)

# %%
#not use

not_use = n.sort_values(ascending=False).head(9) #결측치가 많은 9개의 값을 보겠음
not_use_col = not_use.index  # 열의 값을 보겠음
not_use_col
# Out:
# Index(['호정보', '동정보', '건물부번지', '지점명', '건물명', '층정보', '지번부번지', '표준산업분류코드',
#        '표준산업분류명'],
#       dtype='object')

# %%
print(DateFrame.shape)

df = DateFrame.drop(not_use_col, axis=1)

print(df.shape)


df.info()
# Out:
# (315294, 39)
# (315294, 30)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315294 entries, 0 to 315293
# Data columns (total 30 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     315294 non-null  int64
#  1   상호명        315293 non-null  object
#  2   상권업종대분류코드  315294 non-null  object
#  3   상권업종대분류명   315294 non-null  object
#  4   상권업종중분류코드  315294 non-null  object
#  5   상권업종중분류명   315294 non-null  object
#  6   상권업종소분류코드  315294 non-null  object
#  7   상권업종소분류명   315294 non-null  object
#  8   시도코드       315294 non-null  int64
#  9   시도명        315294 non-null  object
#  10  시군구코드      315294 non-null  int64
#  11  시군구명       315294 non-null  object
#  12  행정동코드      315294 non-null  int64
#  13  행정동명       315289 non-null  object
#  14  법정동코드      315294 non-null  int64
#  15  법정동명       315294 non-null  object
#  16  지번코드       315294 non-null  int64
#  17  대지구분코드     315294 non-null  int64
# ...

# %%
cols = df.columns

# %%
cols_code = cols[cols.str.contains("코드|번호")]
cols_code
# Out:
# Index(['상가업소번호', '상권업종대분류코드', '상권업종중분류코드', '상권업종소분류코드', '시도코드', '시군구코드',
#        '행정동코드', '법정동코드', '지번코드', '대지구분코드', '도로명코드', '건물관리번호', '구우편번호',
#        '신우편번호'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (315294, 30)

# %%
df = df.drop(cols_code, axis=1)

# %%
df
# Out:
#                 상호명  상권업종대분류명    상권업종중분류명   상권업종소분류명    시도명  시군구명  \
# 0             제중건강원        소매     건강/미용식품        건강원  서울특별시  영등포구
# 1             민속악기사        소매   취미/오락관련소매       악기판매  서울특별시   성동구
# 2             태평양진주        소매    시계/귀금속소매     시계/귀금속  서울특별시   종로구
# 3        김선희꼼꼼국어교습소     학문/교육   학원-보습교습입시      학원-입시  서울특별시   송파구
# 4               비지트        음식          한식  한식/백반/한정식  서울특별시   서초구
# ...             ...       ...         ...        ...    ...   ...
# 315289      사라헤어하우스     생활서비스     이/미용/건강      여성미용실  서울특별시   관악구
# 315290   김현진153필라테스  관광/여가/오락   요가/단전/마사지      요가/단식  서울특별시   강동구
# 315291  26도헤어마곡나루역점     생활서비스     이/미용/건강      여성미용실  서울특별시   강서구
# 315292        명품케터링        음식     음식배달서비스     음식출장조달  서울특별시   강북구
# 315293      페어즈오브슈즈        소매  가방/신발/액세서리       신발소매  서울특별시  영등포구
#
#                행정동명    법정동명 대지구분명  지번본번지                    지번주소  \
# 0              영등포동  영등포동5가    대지     41  서울특별시 영등포구 영등포동5가 41-1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315294 entries, 0 to 315293
# Data columns (total 16 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   상호명       315293 non-null  object
#  1   상권업종대분류명  315294 non-null  object
#  2   상권업종중분류명  315294 non-null  object
#  3   상권업종소분류명  315294 non-null  object
#  4   시도명       315294 non-null  object
#  5   시군구명      315294 non-null  object
#  6   행정동명      315289 non-null  object
#  7   법정동명      315294 non-null  object
#  8   대지구분명     315294 non-null  object
#  9   지번본번지     315294 non-null  int64
#  10  지번주소      315294 non-null  object
#  11  도로명       315294 non-null  object
#  12  건물본번지     315294 non-null  int64
#  13  도로명주소     315294 non-null  object
#  14  경도        315294 non-null  float64
#  15  위도        315294 non-null  float64
# dtypes: float64(2), int64(2), object(12)
# memory usage: 38.5+ MB

# %%
df[['상호명']].head() # 대괄호 두개 가 표로 나옴 DF
                            # 대괄호 하나는 series 
df
# Out:
#                 상호명  상권업종대분류명    상권업종중분류명   상권업종소분류명    시도명  시군구명  \
# 0             제중건강원        소매     건강/미용식품        건강원  서울특별시  영등포구
# 1             민속악기사        소매   취미/오락관련소매       악기판매  서울특별시   성동구
# 2             태평양진주        소매    시계/귀금속소매     시계/귀금속  서울특별시   종로구
# 3        김선희꼼꼼국어교습소     학문/교육   학원-보습교습입시      학원-입시  서울특별시   송파구
# 4               비지트        음식          한식  한식/백반/한정식  서울특별시   서초구
# ...             ...       ...         ...        ...    ...   ...
# 315289      사라헤어하우스     생활서비스     이/미용/건강      여성미용실  서울특별시   관악구
# 315290   김현진153필라테스  관광/여가/오락   요가/단전/마사지      요가/단식  서울특별시   강동구
# 315291  26도헤어마곡나루역점     생활서비스     이/미용/건강      여성미용실  서울특별시   강서구
# 315292        명품케터링        음식     음식배달서비스     음식출장조달  서울특별시   강북구
# 315293      페어즈오브슈즈        소매  가방/신발/액세서리       신발소매  서울특별시  영등포구
#
#                행정동명    법정동명 대지구분명  지번본번지                    지번주소  \
# 0              영등포동  영등포동5가    대지     41  서울특별시 영등포구 영등포동5가 41-1
# ...

# %%
df[['상호명','도로명주소']] # 속성이 여러개인데 [] 만 쓰면 series 형식에 맞지 않다 속성이 많으면 dataframe 을 사용해줘야한다
# Out:
#                 상호명                    도로명주소
# 0             제중건강원  서울특별시 영등포구 영중로14길 11-17
# 1             민속악기사         서울특별시 성동구 용답5길 2
# 2             태평양진주     서울특별시 종로구 서순라길 17-10
# 3        김선희꼼꼼국어교습소    서울특별시 송파구 위례성대로12길 31
# 4               비지트      서울특별시 서초구 동광로18길 82
# ...             ...                      ...
# 315289      사라헤어하우스        서울특별시 관악구 관악로 185
# 315290   김현진153필라테스      서울특별시 강동구 양재대로 1517
# 315291  26도헤어마곡나루역점       서울특별시 강서구 마곡서로 152
# 315292        명품케터링     서울특별시 강북구 삼양로19길 113
# 315293      페어즈오브슈즈       서울특별시 영등포구 영중로 116
#
# [315294 rows x 2 columns]

# %%
df.loc[0:3] # 인덱스를 통해서


df.iloc[[0]] # 순서를 통해서

df.loc[df['상호명'] == '제중건강원']
# Out:
#      상호명 상권업종대분류명 상권업종중분류명 상권업종소분류명    시도명  시군구명  행정동명    법정동명 대지구분명  지번본번지  \
# 0  제중건강원       소매  건강/미용식품      건강원  서울특별시  영등포구  영등포동  영등포동5가    대지     41
#
#                      지번주소                도로명  건물본번지                    도로명주소  \
# 0  서울특별시 영등포구 영등포동5가 41-1  서울특별시 영등포구 영중로14길     11  서울특별시 영등포구 영중로14길 11-17
#
#            경도         위도
# 0  126.907168  37.520613

# %%
df.loc[1:3,['상호명']]
# Out:
#           상호명
# 1       민속악기사
# 2       태평양진주
# 3  김선희꼼꼼국어교습소

# %%
df.loc[0:2]
df.loc[[0,1,2]]
# Out:
#      상호명 상권업종대분류명   상권업종중분류명 상권업종소분류명    시도명  시군구명         행정동명    법정동명 대지구분명  \
# 0  제중건강원       소매    건강/미용식품      건강원  서울특별시  영등포구         영등포동  영등포동5가    대지
# 1  민속악기사       소매  취미/오락관련소매     악기판매  서울특별시   성동구          용답동     용답동    대지
# 2  태평양진주       소매   시계/귀금속소매   시계/귀금속  서울특별시   종로구  종로1.2.3.4가동     봉익동    대지
#
#    지번본번지                    지번주소                도로명  건물본번지  \
# 0     41  서울특별시 영등포구 영등포동5가 41-1  서울특별시 영등포구 영중로14길     11
# 1    142    서울특별시 성동구 용답동 142-11     서울특별시 성동구 용답5길      2
# 2     43      서울특별시 종로구 봉익동 43-1     서울특별시 종로구 서순라길     17
#
#                      도로명주소          경도         위도
# 0  서울특별시 영등포구 영중로14길 11-17  126.907168  37.520613
# 1         서울특별시 성동구 용답5길 2  127.049018  37.566857
# 2     서울특별시 종로구 서순라길 17-10  126.993530  37.571848

# %%
cols[-5:]
# Out:
# Index(['도로명주소', '구우편번호', '신우편번호', '경도', '위도'], dtype='object')

# %%
df.iloc[-5:,-5:]
# Out:
#                      도로명  건물본번지                 도로명주소          경도         위도
# 315289     서울특별시 관악구 관악로    185     서울특별시 관악구 관악로 185  126.952644  37.481784
# 315290    서울특별시 강동구 양재대로   1517   서울특별시 강동구 양재대로 1517  127.140855  37.541259
# 315291    서울특별시 강서구 마곡서로    152    서울특별시 강서구 마곡서로 152  126.825623  37.567747
# 315292  서울특별시 강북구 삼양로19길    113  서울특별시 강북구 삼양로19길 113  127.017829  37.617041
# 315293    서울특별시 영등포구 영중로    116    서울특별시 영등포구 영중로 116  126.905938  37.526557

# %%
df.describe(include = 'object')  #각각의 열을 기준으로 데이터(함이나 갯수)를 말함 

#unique 중복값 
#freq 빈도수
# Out:
#            상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명     시도명    시군구명    행정동명    법정동명  \
# count   315293   315294   315294     315294  315294  315294  315289  315294
# unique  227916        8       89        671       1      25     426     464
# top         CU       음식       한식  한식/백반/한정식   서울특별시     강남구    역삼1동     역삼동
# freq      1612   111654    37156      26716  315294   29867    5445    6705
#
#          대지구분명                  지번주소           도로명             도로명주소
# count   315294                315294        315294            315294
# unique       2                125065         12123            124398
# top         대지  서울특별시 종로구 종로6가 262-1  서울특별시 종로구 종로  서울특별시 종로구 종로 266
# freq    314994                   883          2130               896

# %%
df['상권업종대분류명'].unique()  # 중복을 제외한 값
# Out:
# array(['소매', '학문/교육', '음식', '부동산', '생활서비스', '관광/여가/오락', '숙박', '스포츠'],
#       dtype=object)

# %%
len(df['상권업종대분류명'].unique())
# Out:
# 8

# %%
df['상권업종대분류명'].nunique()  #unique의 number의 붙인 nunique를 해준다
# Out:
# 8

# %%
df['상권업종대분류명'].mode() #object명의 가장 많은 횟수
# Out:
# 0    음식
# dtype: object

# %%
df.describe() # std 표준 편차
# Out:
#                지번본번지          건물본번지             경도             위도
# count  315294.000000  315294.000000  315294.000000  315294.000000
# mean      416.377242     140.687076     126.994451      37.545334
# std       422.422749     260.018839       0.083680       0.049078
# min         0.000000       1.000000     126.768169      37.434081
# 25%       100.000000      19.000000     126.923287      37.504884
# 50%       295.000000      47.000000     127.009408      37.542790
# 75%       636.000000     157.000000     127.056499      37.572987
# max      9999.000000    3318.000000     127.182588      37.690787

# %%
df[['경도','위도']].describe()
# Out:
#                   경도             위도
# count  315294.000000  315294.000000
# mean      126.994451      37.545334
# std         0.083680       0.049078
# min       126.768169      37.434081
# 25%       126.923287      37.504884
# 50%       127.009408      37.542790
# 75%       127.056499      37.572987
# max       127.182588      37.690787

# %%
df['위도'].count()

df['위도'].mean()

df['위도'].max()

df['위도'].min()

df['위도'].quantile(q=0.25)  # % 접근하는 법

print(df['위도'].median()) #중간 값
df['위도'].quantile(q=0.5) # 중간에 있는 값  기본값은  0.5
# Out:
# 37.5427896308174
# 37.5427896308174

# %%
df.loc[0]['상호명']


df.loc[0,'상호명']
# Out:
# '제중건강원'

# %%
df.loc[[0,1,2], '상호명']

df.loc[[0,1,2], ['상호명']]
# Out:
#      상호명
# 0  제중건강원
# 1  민속악기사
# 2  태평양진주

# %%
df.loc[[0,1,2], ['상호명','도로명']]
# Out:
#      상호명                도로명
# 0  제중건강원  서울특별시 영등포구 영중로14길
# 1  민속악기사     서울특별시 성동구 용답5길
# 2  태평양진주     서울특별시 종로구 서순라길

# %%
df.iloc[:].shape


df.iloc[0:5,0:5]
# Out:
#           상호명 상권업종대분류명   상권업종중분류명   상권업종소분류명    시도명
# 0       제중건강원       소매    건강/미용식품        건강원  서울특별시
# 1       민속악기사       소매  취미/오락관련소매       악기판매  서울특별시
# 2       태평양진주       소매   시계/귀금속소매     시계/귀금속  서울특별시
# 3  김선희꼼꼼국어교습소    학문/교육  학원-보습교습입시      학원-입시  서울특별시
# 4         비지트       음식         한식  한식/백반/한정식  서울특별시

# %%
cols
# Out:
# Index(['상가업소번호', '상호명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명',
#        '상권업종소분류코드', '상권업종소분류명', '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드',
#        '행정동명', '법정동코드', '법정동명', '지번코드', '대지구분코드', '대지구분명', '지번본번지', '지번주소',
#        '도로명코드', '도로명', '건물본번지', '건물관리번호', '도로명주소', '구우편번호', '신우편번호', '경도',
#        '위도'],
#       dtype='object')

# %%
df['상권업종대분류명'] == '음식'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 315289    False
# 315290    False
# 315291    False
# 315292     True
# 315293    False
# Name: 상권업종대분류명, Length: 315294, dtype: bool

# %%
df_food = df[df['상권업종대분류명'] == '음식'].copy() # copy 복사 하는 함수

df_food
# Out:
#                   상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명    시도명 시군구명         행정동명  \
# 4                 비지트       음식       한식    한식/백반/한정식  서울특별시  서초구         방배4동
# 5                쓰리에프       음식       한식    한식/백반/한정식  서울특별시  동작구         사당2동
# 6                  채움       음식       한식    한식/백반/한정식  서울특별시  종로구  종로1.2.3.4가동
# 7                  다향       음식       한식    한식/백반/한정식  서울특별시  서초구         서초3동
# 8              고향생막걸리       음식     유흥주점         민속주점  서울특별시  강남구         압구정동
# ...               ...      ...      ...          ...    ...  ...          ...
# 315261           궁정만두       음식       분식    국수/만두/칼국수  서울특별시  강남구         역삼1동
# 315277          컴포즈커피       음식   커피점/카페  커피전문점/카페/다방  서울특별시  은평구         응암1동
# 315278  돼지코생곱창갈비잠실새내점       음식       한식     곱창/양구이전문  서울특별시  송파구         잠실본동
# 315281         커스텀샐러드       음식       한식    한식/백반/한정식  서울특별시  관악구          신림동
# 315292          명품케터링       음식  음식배달서비스       음식출장조달  서울특별시  강북구         삼각산동
#
# ...

# %%
df[df['시군구명'] == '강남구'].head(5)
# Out:
#              상호명 상권업종대분류명   상권업종중분류명 상권업종소분류명    시도명 시군구명  행정동명 법정동명 대지구분명  \
# 8         고향생막걸리       음식       유흥주점     민속주점  서울특별시  강남구  압구정동  신사동    대지
# 19      호랑이가만든족발       음식         한식  족발/보쌈전문  서울특별시  강남구  역삼1동  역삼동    대지
# 25    대동석유압구정주유소    생활서비스    주유소/충전소      주유소  서울특별시  강남구  압구정동  신사동    대지
# 33  캐논비즈니스프라자전시장       소매  사무/문구/컴퓨터  사무용기기소매  서울특별시  강남구  삼성1동  삼성동    대지
# 36           소낙스    생활서비스    자동차/이륜차      세차장  서울특별시  강남구  역삼1동  역삼동    대지
#
#     지번본번지                  지번주소                도로명  건물본번지  \
# 8     615   서울특별시 강남구 신사동 615-1     서울특별시 강남구 압구정로    216
# 19    704   서울특별시 강남구 역삼동 704-4  서울특별시 강남구 테헤란로43길     28
# 25    633     서울특별시 강남구 신사동 633      서울특별시 강남구 언주로    842
# 33    168  서울특별시 강남구 삼성동 168-12     서울특별시 강남구 테헤란로    607
# 36    694  서울특별시 강남구 역삼동 694-25      서울특별시 강남구 선릉로    537
#
#                    도로명주소          경도         위도
# 8     서울특별시 강남구 압구정로 216  127.031012  37.528073
# 19  서울특별시 강남구 테헤란로43길 28  127.044182  37.504996
# ...

# %%
df[(df['시군구명'] == '강남구') & (df['상권업종대분류명'] =='음식')]


df[(df['시군구명'] == '강남구') & (df['상권업종대분류명'] == '음식')]['상권업종중분류명'].value_counts()
# Out:
# 한식         3446
# 커피점/카페     2034
# 양식         1136
# 일식/수산물      927
# 유흥주점        823
# 분식          740
# 패스트푸드       479
# 제과제빵떡케익     429
# 닭/오리요리      328
# 중식          289
# 별식/퓨전요리     188
# 기타음식업        46
# 부페           45
# 음식배달서비스      10
# Name: 상권업종중분류명, dtype: int64

# %%
df.loc[(df['시군구명'] == '강남구') & (df['상권업종대분류명'] == '음식'), '상권업종대분류명'].value_counts()
# Out:
# 음식    10920
# Name: 상권업종대분류명, dtype: int64

# %%
# 시도명이 서울특별시고 이고 상권업종 대분류명이 음식인 정보를 df_seoul_food에 담기 
# copy를 안하면 원본 데이터의 영향을 미친다

df_seoul_food = df.loc[(df['시도명'] == '서울특별시') & (df['상권업종대분류명'] == '음식')]

# %%
df_seoul_food
# Out:
#                   상호명 상권업종대분류명 상권업종중분류명     상권업종소분류명    시도명 시군구명         행정동명  \
# 4                 비지트       음식       한식    한식/백반/한정식  서울특별시  서초구         방배4동
# 5                쓰리에프       음식       한식    한식/백반/한정식  서울특별시  동작구         사당2동
# 6                  채움       음식       한식    한식/백반/한정식  서울특별시  종로구  종로1.2.3.4가동
# 7                  다향       음식       한식    한식/백반/한정식  서울특별시  서초구         서초3동
# 8              고향생막걸리       음식     유흥주점         민속주점  서울특별시  강남구         압구정동
# ...               ...      ...      ...          ...    ...  ...          ...
# 315261           궁정만두       음식       분식    국수/만두/칼국수  서울특별시  강남구         역삼1동
# 315277          컴포즈커피       음식   커피점/카페  커피전문점/카페/다방  서울특별시  은평구         응암1동
# 315278  돼지코생곱창갈비잠실새내점       음식       한식     곱창/양구이전문  서울특별시  송파구         잠실본동
# 315281         커스텀샐러드       음식       한식    한식/백반/한정식  서울특별시  관악구          신림동
# 315292          명품케터링       음식  음식배달서비스       음식출장조달  서울특별시  강북구         삼각산동
#
# ...

# %%
list1 = {'직업':['프로그래머','마케팅','보안'],
         '이름':['임상운','박서현','임정운'],
         '용돈':['20000','30000','2000000']}


df2 = pd.DataFrame(list1)

# %%
df2
# Out:
#       직업   이름       용돈
# 0  프로그래머  임상운    20000
# 1    마케팅  박서현    30000
# 2     보안  임정운  2000000

# %%
df2.loc[(df2['직업'] == '프로그래머') & (df2['이름'] == '임상운')]
# Out:
#       직업   이름     용돈
# 0  프로그래머  임상운  20000

# %%
df2
# Out:
#       직업   이름       용돈
# 0  프로그래머  임상운    20000
# 1    마케팅  박서현    30000
# 2     보안  임정운  2000000

# %%
Data1 = df2.loc[(df2['직업'] == '프로그래머') & (df2['이름'] == '임상운')]

# %%
Data1.drop(0)
# Out:
# Empty DataFrame
# Columns: [직업, 이름, 용돈]
# Index: []

# %%
df2
# Out:
#       직업   이름       용돈
# 0  프로그래머  임상운    20000
# 1    마케팅  박서현    30000
# 2     보안  임정운  2000000

# %%
# 시군구면 상권업종 분류명으로 그룹화 하여 상점수를 카운트하기

food_gu = df_seoul_food.groupby(['시군구명','상권업종중분류명'])['상호명'].count()

# %%
food_gu
# Out:
# 시군구명  상권업종중분류명
# 강남구   기타음식업         46
#       닭/오리요리       328
#       별식/퓨전요리      188
#       부페            45
#       분식           740
#                   ...
# 중랑구   제과제빵떡케익      142
#       중식            70
#       커피점/카페       459
#       패스트푸드        162
#       한식          1181
# Name: 상호명, Length: 349, dtype: int64

# %%
#food_gu = df_seoul_food.pivot_table(index=['시군구명','상권업종중분류명'],values=['경도'],aggfunc='count')

# %%
food_gu
# Out:
# 시군구명  상권업종중분류명
# 강남구   기타음식업         46
#       닭/오리요리       328
#       별식/퓨전요리      188
#       부페            45
#       분식           740
#                   ...
# 중랑구   제과제빵떡케익      142
#       중식            70
#       커피점/카페       459
#       패스트푸드        162
#       한식          1181
# Name: 상호명, Length: 349, dtype: int64

# %%
food_gu.plot()

# %%
food_gu.plot()

# %%
food_gu.unstack()
# Out:
# 상권업종중분류명  기타음식업  닭/오리요리  별식/퓨전요리    부페     분식      양식   유흥주점  음식배달서비스  일식/수산물  \
# 시군구명
# 강남구        46.0   328.0    188.0  45.0  740.0  1136.0  823.0     10.0   927.0
# 강동구         6.0   256.0     99.0  24.0  404.0   131.0  473.0      3.0   350.0
# 강북구         4.0   210.0     67.0   6.0  305.0    79.0  379.0      3.0   188.0
# 강서구        28.0   306.0    118.0  18.0  478.0   314.0  564.0      1.0   425.0
# 관악구        13.0   245.0     95.0  12.0  401.0   240.0  534.0      3.0   299.0
# 광진구        14.0   219.0     83.0  12.0  401.0   188.0  430.0      1.0   308.0
# 구로구        14.0   267.0     98.0  18.0  368.0    94.0  557.0      3.0   227.0
# 금천구        12.0   162.0     74.0  14.0  255.0    80.0  315.0      2.0   164.0
# 노원구        14.0   292.0     84.0   9.0  382.0   123.0  352.0      7.0   234.0
# 도봉구         9.0   178.0     52.0  11.0  253.0    77.0  226.0      1.0   171.0
# 동대문구        6.0   202.0     85.0  15.0  344.0   110.0  374.0      5.0   234.0
# ...

# %%
food_gu.unstack().plot.bar().legend(loc='upper right')

# %%
food_gu.unstack().loc['강남구'].plot.bar()

# %%
food_gu.unstack().loc['강남구']
# Out:
# 상권업종중분류명
# 기타음식업        46.0
# 닭/오리요리      328.0
# 별식/퓨전요리     188.0
# 부페           45.0
# 분식          740.0
# 양식         1136.0
# 유흥주점        823.0
# 음식배달서비스      10.0
# 일식/수산물      927.0
# 제과제빵떡케익     429.0
# 중식          289.0
# 커피점/카페     2034.0
# 패스트푸드       479.0
# 한식         3446.0
# Name: 강남구, dtype: float64

# %%
food_gu.unstack().loc['강남구'][:5][:5]
# Out:
# 상권업종중분류명
# 기타음식업       46.0
# 닭/오리요리     328.0
# 별식/퓨전요리    188.0
# 부페          45.0
# 분식         740.0
# Name: 강남구, dtype: float64

# %%
food_gu.unstack().iloc[:5,:5]
# Out:
# 상권업종중분류명  기타음식업  닭/오리요리  별식/퓨전요리    부페     분식
# 시군구명
# 강남구        46.0   328.0    188.0  45.0  740.0
# 강동구         6.0   256.0     99.0  24.0  404.0
# 강북구         4.0   210.0     67.0   6.0  305.0
# 강서구        28.0   306.0    118.0  18.0  478.0
# 관악구        13.0   245.0     95.0  12.0  401.0

# %%
food = food_gu.reset_index()

# %%
food
# Out:
#     시군구명 상권업종중분류명   상호명
# 0    강남구    기타음식업    46
# 1    강남구   닭/오리요리   328
# 2    강남구  별식/퓨전요리   188
# 3    강남구       부페    45
# 4    강남구       분식   740
# ..   ...      ...   ...
# 344  중랑구  제과제빵떡케익   142
# 345  중랑구       중식    70
# 346  중랑구   커피점/카페   459
# 347  중랑구    패스트푸드   162
# 348  중랑구       한식  1181
#
# [349 rows x 3 columns]

# %%
food = food.rename(columns = {'상호명':'상호수'})

# %%
food
# Out:
#     시군구명 상권업종중분류명   상호수
# 0    강남구    기타음식업    46
# 1    강남구   닭/오리요리   328
# 2    강남구  별식/퓨전요리   188
# 3    강남구       부페    45
# 4    강남구       분식   740
# ..   ...      ...   ...
# 344  중랑구  제과제빵떡케익   142
# 345  중랑구       중식    70
# 346  중랑구   커피점/카페   459
# 347  중랑구    패스트푸드   162
# 348  중랑구       한식  1181
#
# [349 rows x 3 columns]

# %%
plt.figure(figsize =(20,10))
sns.barplot(data = food, x ='시군구명',y = '상호수')
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize =(20,10))
sns.barplot(data = food, x ='시군구명',y = '상호수' ,hue='상권업종중분류명').legend(loc='upper right')

# %%
plt.figure(figsize =(15,10))
sns.barplot(data = food, x ='상권업종중분류명',y = '상호수' ,hue='상권업종중분류명').legend(loc='upper left')

# %%
sns.catplot(data = food, x = '상권업종중분류명',y='상호수')

# %%
sns.catplot(data = food, x = '상권업종중분류명',y='상호수',kind = 'bar')

# %%
sns.catplot(data = food, x = '상권업종중분류명',y='상호수',kind = 'bar',col='시군구명')

# %%
sns.catplot(data = food, x = '상권업종중분류명',y='상호수',kind = 'bar',col='시군구명', col_wrap=2)
